# %% [markdown]
# # 05 Dashboard Prep
#
# Create the lightweight dashboard dataset used by `streamlit run src/dashboard/app.py`.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.insert(0, str(ROOT))

from src.pipeline.config import load_config
from src.pipeline.dashboard_prep import build_dashboard_dataset

config = load_config(ROOT / 'configs' / 'chaiyaphum_2.yaml')

# %%
build_dashboard_dataset(config)
